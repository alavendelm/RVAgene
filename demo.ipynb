# %% [markdown]
# ## Section 1 : Generating synthetic data

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from numpy.random import randint
import sys
import os
import warnings
warnings.filterwarnings('ignore')

method = "convolve"  ## options: add or convolve
dataset = "demosim"  ## name of generated datset
nclusters = 4        ## number of clusters in data
ngenes = [20]*nclusters ## 20 genes per cluster 
length = 100         ## 100 timepoints per gene 
x= np.linspace(0,length/1000,length)  ## spanned over a range 0 to 0.1
data = []           ## initialize data list

# %%
for i in range(nclusters): ### for each cluster 
    if(method == "add"): ## find a mean function by adding a sin and a cos and then scaling 
        y = randint(0,100)*np.sin(randint(0,100)*x)+randint(0,100)*np.cos(randint(0,100)*x) 
        y = MinMaxScaler(feature_range=(-1,1)).fit_transform(y.reshape(-1, 1)).reshape(-1)
    elif(method == "convolve"): ## find a mean function by convolving a sin and a cos and then scaling 
        y = np.convolve(randint(0,100)*np.sin(randint(0,100)*x), randint(0,100)*np.cos(randint(0,100)*x), 'same')
        y = MinMaxScaler(feature_range=(-1,1)).fit_transform(y.reshape(-1, 1)).reshape(-1)
    else:
        print("not implemented")
        sys.exit()
    y_vec = y[:,np.newaxis] + 0.1
    cov = np.dot(y_vec,y_vec.T)/np.dot(y.T,y) ## compute YY^T as covariance
    del(y_vec)
    for m in range(cov.shape[0]):   ## make elements in cov with indices too far (50 chosen here) from each other 0
        for n in range(cov.shape[1]):
            if(abs(m-n) > 50):
                cov[m][n] = 0

    for gene in range(ngenes[i]):   ## sample member genes for each cluster using mean function and cov
        exp = np.random.multivariate_normal(y,cov)
        #exp = exp + np.random.normal(0,0.1,y.shape[0])
        data.append([str(i)] + [str(j) for j in exp.tolist()])
        plt.plot(x,exp,alpha=0.8,linewidth=0.9)
    plt.plot(x,y, color="#000000", label="cluster mean")
    plt.savefig("./figs/cluster_" + dataset + str(i) + ".png", dpi = 500)
    plt.show()
    plt.close()

# %%
## write data to proper location
if(not os.path.exists("./data/"+dataset)):
    os.mkdir("./data/"+dataset)
f = open("./data/"+dataset+"/"+dataset+"_TRAIN","w")
f.write("\n".join([",".join(row) for row in data]))
f.close()

f = open("./data/"+dataset+"/"+dataset+"_TEST","w") ## dummy test file (same as train file), modify as needed
f.write("\n".join([",".join(row) for row in data[:2]]))
f.close()

print("generated synthetic data at ./data/" + dataset)
print("true clusters of generated data plotted at ./figs/" + dataset)
# Out:
# generated synthetic data at ./data/demosim
# true clusters of generated data plotted at ./figs/demosim

# %% [markdown]
# ## Section 2: Define and train RVAgene on the generated data

# %%
from rvagene.rvagene import RVAgene
from rvagene.utils import open_data
import numpy as np
import torch
import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt
from matplotlib.patches import Patch
from mpl_toolkits.mplot3d import Axes3D
from torch.utils.data import TensorDataset
import sys

### model params ###
hidden_size = 70
hidden_layer_depth = 1
latent_length = 3
batch_size = 20
learning_rate = 0.003
n_epochs = 400
dropout_rate = 0.2
optimizer = 'Adam' # options: ADAM, SGD
cuda = False # options: True, False
print_every=30
clip = True # options: True, False
max_grad_norm=5
loss = 'MSELoss' # options: SmoothL1Loss, MSELoss
dataset='demosim'

X_train, _, y_train, _ = open_data('data', ratio_train=1, dataset=dataset)

num_classes = len(np.unique(y_train))
base = np.min(y_train)  # Check if data is 0-based
if base != 0:
    y_train -= base


train_dataset = TensorDataset(torch.from_numpy(X_train))


sequence_length = X_train.shape[1]
number_of_features = X_train.shape[2]

rvagene = RVAgene(sequence_length=sequence_length,
            number_of_features = number_of_features,
            hidden_size = hidden_size,
            hidden_layer_depth = hidden_layer_depth,
            latent_length = latent_length,
            batch_size = batch_size,
            learning_rate = learning_rate,
            n_epochs = n_epochs,
            dropout_rate = dropout_rate,
            optimizer = optimizer,
            cuda = cuda,
            print_every=print_every,
            clip=clip,
            max_grad_norm=max_grad_norm,
            loss = loss)

rvagene.fit(train_dataset)
# Out:
# Epoch: 0
# Average loss: 1279.7929
# Epoch: 1
# Average loss: 1256.6028
# Epoch: 2
# Average loss: 1235.4945
# Epoch: 3
# Average loss: 1233.9424
# Epoch: 4
# Average loss: 1241.4847
# Epoch: 5
# Average loss: 1235.2867
# Epoch: 6
# Average loss: 1234.7297
# Epoch: 7
# Average loss: 1226.8190
# Epoch: 8
# Average loss: 1225.1229
# Epoch: 9
# Average loss: 1181.8371
# Epoch: 10
# Average loss: 1304.2514
# Epoch: 11
# Average loss: 1113.8208
# Epoch: 12
# Average loss: 1118.3392
# Epoch: 13
# Average loss: 1110.0762
# Epoch: 14
# Average loss: 1088.6454
# Epoch: 15
# Average loss: 1079.7677
# Epoch: 16
# Average loss: 1074.4970
# Epoch: 17
# Average loss: 1062.4552
# Epoch: 18
# Average loss: 1063.0640
# Epoch: 19
# Average loss: 1055.6290
# Epoch: 20
# Average loss: 1076.8723
# Epoch: 21
# Average loss: 1054.9793
# Epoch: 22
# Average loss: 1031.8666
# Epoch: 23
# Average loss: 1052.1170
# Epoch: 24
# Average loss: 1050.6658
# Epoch: 25
# Average loss: 1023.6735
# Epoch: 26
# Average loss: 1062.7726
# Epoch: 27
# Average loss: 1033.3347
# Epoch: 28
# Average loss: 1002.7791
# Epoch: 29
# Average loss: 957.9014
# Epoch: 30
# Average loss: 934.3671
# Epoch: 31
# Average loss: 905.0314
# Epoch: 32
# Average loss: 903.5352
# Epoch: 33
# Average loss: 928.1139
# Epoch: 34
# Average loss: 887.8624
# Epoch: 35
# Average loss: 883.9571
# Epoch: 36
# Average loss: 870.4175
# Epoch: 37
# Average loss: 849.4350
# Epoch: 38
# Average loss: 845.2387
# Epoch: 39
# Average loss: 828.6777
# Epoch: 40
# Average loss: 812.4591
# Epoch: 41
# Average loss: 829.3789
# Epoch: 42
# Average loss: 818.9184
# Epoch: 43
# Average loss: 814.0198
# Epoch: 44
# Average loss: 819.4280
# Epoch: 45
# Average loss: 826.7132
# Epoch: 46
# Average loss: 756.6074
# Epoch: 47
# Average loss: 634.8684
# Epoch: 48
# Average loss: 911.1971
# Epoch: 49
# Average loss: 637.6437
# Epoch: 50
# Average loss: 656.8146
# Epoch: 51
# Average loss: 645.5295
# Epoch: 52
# Average loss: 542.6542
# Epoch: 53
# Average loss: 675.6240
# Epoch: 54
# Average loss: 508.3070
# Epoch: 55
# Average loss: 547.0959
# Epoch: 56
# Average loss: 535.8538
# Epoch: 57
# Average loss: 462.2218
# Epoch: 58
# Average loss: 550.6685
# Epoch: 59
# Average loss: 460.9136
# Epoch: 60
# Average loss: 459.3884
# Epoch: 61
# Average loss: 459.9755
# Epoch: 62
# Average loss: 436.8092
# Epoch: 63
# Average loss: 436.7645
# Epoch: 64
# Average loss: 368.0636
# Epoch: 65
# Average loss: 372.3293
# Epoch: 66
# Average loss: 369.2074
# Epoch: 67
# Average loss: 351.6676
# Epoch: 68
# Average loss: 359.6184
# Epoch: 69
# Average loss: 346.1211
# Epoch: 70
# Average loss: 378.8973
# Epoch: 71
# Average loss: 347.2655
# Epoch: 72
# Average loss: 376.7428
# Epoch: 73
# Average loss: 335.3183
# Epoch: 74
# Average loss: 285.7238
# Epoch: 75
# Average loss: 250.8502
# Epoch: 76
# Average loss: 236.6864
# Epoch: 77
# Average loss: 249.6996
# Epoch: 78
# Average loss: 256.6041
# Epoch: 79
# Average loss: 233.6136
# Epoch: 80
# Average loss: 276.3933
# Epoch: 81
# Average loss: 242.4403
# Epoch: 82
# Average loss: 253.7614
# Epoch: 83
# Average loss: 209.1795
# Epoch: 84
# Average loss: 338.6661
# Epoch: 85
# Average loss: 491.6532
# Epoch: 86
# Average loss: 402.3964
# Epoch: 87
# Average loss: 329.5414
# Epoch: 88
# Average loss: 366.1765
# Epoch: 89
# Average loss: 396.9720
# Epoch: 90
# Average loss: 460.0698
# Epoch: 91
# Average loss: 544.0818
# Epoch: 92
# Average loss: 313.9416
# Epoch: 93
# Average loss: 321.6979
# Epoch: 94
# Average loss: 256.7319
# Epoch: 95
# Average loss: 250.7689
# Epoch: 96
# Average loss: 215.0207
# Epoch: 97
# Average loss: 193.3477
# Epoch: 98
# Average loss: 202.7938
# Epoch: 99
# Average loss: 200.4983
# Epoch: 100
# Average loss: 175.4402
# Epoch: 101
# Average loss: 166.0075
# Epoch: 102
# Average loss: 167.3772
# Epoch: 103
# Average loss: 175.3225
# Epoch: 104
# Average loss: 172.9012
# Epoch: 105
# Average loss: 177.1517
# Epoch: 106
# Average loss: 140.9750
# Epoch: 107
# Average loss: 153.2956
# Epoch: 108
# Average loss: 143.1094
# Epoch: 109
# Average loss: 146.3649
# Epoch: 110
# Average loss: 156.3282
# Epoch: 111
# Average loss: 148.4467
# Epoch: 112
# Average loss: 154.2117
# Epoch: 113
# Average loss: 151.6795
# Epoch: 114
# Average loss: 151.9174
# Epoch: 115
# Average loss: 134.0196
# Epoch: 116
# Average loss: 167.6279
# Epoch: 117
# Average loss: 192.5964
# Epoch: 118
# Average loss: 175.2733
# Epoch: 119
# Average loss: 162.4412
# Epoch: 120
# Average loss: 188.4714
# Epoch: 121
# Average loss: 153.9240
# Epoch: 122
# Average loss: 166.9110
# Epoch: 123
# Average loss: 138.3354
# Epoch: 124
# Average loss: 139.5400
# Epoch: 125
# Average loss: 123.5995
# Epoch: 126
# Average loss: 122.0013
# Epoch: 127
# Average loss: 125.9477
# Epoch: 128
# Average loss: 115.7082
# Epoch: 129
# Average loss: 110.2051
# Epoch: 130
# Average loss: 119.8161
# Epoch: 131
# Average loss: 108.3852
# Epoch: 132
# Average loss: 132.4241
# Epoch: 133
# Average loss: 125.5383
# Epoch: 134
# Average loss: 118.1482
# Epoch: 135
# Average loss: 106.0628
# Epoch: 136
# Average loss: 106.9478
# Epoch: 137
# Average loss: 113.7576
# Epoch: 138
# Average loss: 104.3034
# Epoch: 139
# Average loss: 99.3489
# Epoch: 140
# Average loss: 115.3443
# Epoch: 141
# Average loss: 93.2921
# Epoch: 142
# Average loss: 109.0138
# Epoch: 143
# Average loss: 98.3646
# Epoch: 144
# Average loss: 113.8629
# Epoch: 145
# Average loss: 100.0117
# Epoch: 146
# Average loss: 103.0032
# Epoch: 147
# Average loss: 100.2866
# Epoch: 148
# Average loss: 109.8397
# Epoch: 149
# Average loss: 125.5785
# Epoch: 150
# Average loss: 132.0810
# Epoch: 151
# Average loss: 120.6839
# Epoch: 152
# Average loss: 120.6108
# Epoch: 153
# Average loss: 122.9941
# Epoch: 154
# Average loss: 103.3046
# Epoch: 155
# Average loss: 125.8754
# Epoch: 156
# Average loss: 105.0218
# Epoch: 157
# Average loss: 117.6754
# Epoch: 158
# Average loss: 114.1294
# Epoch: 159
# Average loss: 103.6562
# Epoch: 160
# Average loss: 103.7938
# Epoch: 161
# Average loss: 104.3473
# Epoch: 162
# Average loss: 100.5203
# Epoch: 163
# Average loss: 90.6497
# Epoch: 164
# Average loss: 101.1134
# Epoch: 165
# Average loss: 99.1877
# Epoch: 166
# Average loss: 96.5658
# Epoch: 167
# Average loss: 97.2847
# Epoch: 168
# Average loss: 108.4127
# Epoch: 169
# Average loss: 88.6391
# Epoch: 170
# Average loss: 109.3924
# Epoch: 171
# Average loss: 88.5001
# Epoch: 172
# Average loss: 81.8448
# Epoch: 173
# Average loss: 71.6018
# Epoch: 174
# Average loss: 68.2384
# Epoch: 175
# Average loss: 78.0666
# Epoch: 176
# Average loss: 67.1594
# Epoch: 177
# Average loss: 92.3341
# Epoch: 178
# Average loss: 69.9335
# Epoch: 179
# Average loss: 73.1103
# Epoch: 180
# Average loss: 80.8475
# Epoch: 181
# Average loss: 73.8105
# Epoch: 182
# Average loss: 76.4600
# Epoch: 183
# Average loss: 71.8965
# Epoch: 184
# Average loss: 74.7795
# Epoch: 185
# Average loss: 70.6901
# Epoch: 186
# Average loss: 70.6804
# Epoch: 187
# Average loss: 66.3908
# Epoch: 188
# Average loss: 63.9558
# Epoch: 189
# Average loss: 63.5424
# Epoch: 190
# Average loss: 66.5604
# Epoch: 191
# Average loss: 88.6369
# Epoch: 192
# Average loss: 108.5526
# Epoch: 193
# Average loss: 82.7576
# Epoch: 194
# Average loss: 88.9958
# Epoch: 195
# Average loss: 88.4966
# Epoch: 196
# Average loss: 83.7847
# Epoch: 197
# Average loss: 77.5146
# Epoch: 198
# Average loss: 88.8273
# Epoch: 199
# Average loss: 74.8029
# Epoch: 200
# Average loss: 82.8929
# Epoch: 201
# Average loss: 86.1249
# Epoch: 202
# Average loss: 79.9697
# Epoch: 203
# Average loss: 76.2614
# Epoch: 204
# Average loss: 90.6898
# Epoch: 205
# Average loss: 73.7987
# Epoch: 206
# Average loss: 70.9773
# Epoch: 207
# Average loss: 63.4145
# Epoch: 208
# Average loss: 64.5857
# Epoch: 209
# Average loss: 68.5082
# Epoch: 210
# Average loss: 65.8562
# Epoch: 211
# Average loss: 62.9278
# Epoch: 212
# Average loss: 70.4951
# Epoch: 213
# Average loss: 70.9430
# Epoch: 214
# Average loss: 70.8053
# Epoch: 215
# Average loss: 69.4483
# Epoch: 216
# Average loss: 68.9278
# Epoch: 217
# Average loss: 65.0246
# Epoch: 218
# Average loss: 70.6311
# Epoch: 219
# Average loss: 62.2809
# Epoch: 220
# Average loss: 67.9359
# Epoch: 221
# Average loss: 71.4869
# Epoch: 222
# Average loss: 79.9491
# Epoch: 223
# Average loss: 69.0634
# Epoch: 224
# Average loss: 70.8590
# Epoch: 225
# Average loss: 65.2374
# Epoch: 226
# Average loss: 63.2501
# Epoch: 227
# Average loss: 64.2144
# Epoch: 228
# Average loss: 65.0215
# Epoch: 229
# Average loss: 74.1353
# Epoch: 230
# Average loss: 66.6709
# Epoch: 231
# Average loss: 67.6714
# Epoch: 232
# Average loss: 62.0593
# Epoch: 233
# Average loss: 66.6973
# Epoch: 234
# Average loss: 86.4029
# Epoch: 235
# Average loss: 78.0775
# Epoch: 236
# Average loss: 183.2461
# Epoch: 237
# Average loss: 101.8906
# Epoch: 238
# Average loss: 97.9874
# Epoch: 239
# Average loss: 87.4755
# Epoch: 240
# Average loss: 80.9682
# Epoch: 241
# Average loss: 88.4649
# Epoch: 242
# Average loss: 76.7267
# Epoch: 243
# Average loss: 80.5016
# Epoch: 244
# Average loss: 72.9031
# Epoch: 245
# Average loss: 64.2397
# Epoch: 246
# Average loss: 74.8516
# Epoch: 247
# Average loss: 84.6725
# Epoch: 248
# Average loss: 66.9202
# Epoch: 249
# Average loss: 63.7592
# Epoch: 250
# Average loss: 66.4092
# Epoch: 251
# Average loss: 81.9820
# Epoch: 252
# Average loss: 81.5464
# Epoch: 253
# Average loss: 63.7549
# Epoch: 254
# Average loss: 66.9408
# Epoch: 255
# Average loss: 66.6047
# Epoch: 256
# Average loss: 64.4354
# Epoch: 257
# Average loss: 63.5834
# Epoch: 258
# Average loss: 67.8653
# Epoch: 259
# Average loss: 59.6808
# Epoch: 260
# Average loss: 60.4728
# Epoch: 261
# Average loss: 62.7991
# Epoch: 262
# Average loss: 61.6829
# Epoch: 263
# Average loss: 59.8321
# Epoch: 264
# Average loss: 61.4274
# Epoch: 265
# Average loss: 62.4130
# Epoch: 266
# Average loss: 73.8461
# Epoch: 267
# Average loss: 68.4005
# Epoch: 268
# Average loss: 65.9401
# Epoch: 269
# Average loss: 67.3670
# Epoch: 270
# Average loss: 67.8044
# Epoch: 271
# Average loss: 68.6486
# Epoch: 272
# Average loss: 64.6908
# Epoch: 273
# Average loss: 71.3768
# Epoch: 274
# Average loss: 85.7019
# Epoch: 275
# Average loss: 70.4028
# Epoch: 276
# Average loss: 71.1765
# Epoch: 277
# Average loss: 80.2116
# Epoch: 278
# Average loss: 65.9421
# Epoch: 279
# Average loss: 64.9653
# Epoch: 280
# Average loss: 71.7358
# Epoch: 281
# Average loss: 76.8878
# Epoch: 282
# Average loss: 78.7209
# Epoch: 283
# Average loss: 83.7990
# Epoch: 284
# Average loss: 75.1310
# Epoch: 285
# Average loss: 80.1226
# Epoch: 286
# Average loss: 68.2480
# Epoch: 287
# Average loss: 78.6152
# Epoch: 288
# Average loss: 64.3824
# Epoch: 289
# Average loss: 61.5174
# Epoch: 290
# Average loss: 60.9468
# Epoch: 291
# Average loss: 60.9180
# Epoch: 292
# Average loss: 61.4772
# Epoch: 293
# Average loss: 61.2088
# Epoch: 294
# Average loss: 60.0111
# Epoch: 295
# Average loss: 57.7208
# Epoch: 296
# Average loss: 60.0543
# Epoch: 297
# Average loss: 63.1585
# Epoch: 298
# Average loss: 63.7159
# Epoch: 299
# Average loss: 76.4111
# Epoch: 300
# Average loss: 71.4824
# Epoch: 301
# Average loss: 62.3647
# Epoch: 302
# Average loss: 66.0321
# Epoch: 303
# Average loss: 63.2358
# Epoch: 304
# Average loss: 60.8720
# Epoch: 305
# Average loss: 60.3027
# Epoch: 306
# Average loss: 65.6749
# Epoch: 307
# Average loss: 75.8701
# Epoch: 308
# Average loss: 73.1774
# Epoch: 309
# Average loss: 67.9253
# Epoch: 310
# Average loss: 73.1072
# Epoch: 311
# Average loss: 72.3023
# Epoch: 312
# Average loss: 63.9388
# Epoch: 313
# Average loss: 63.6073
# Epoch: 314
# Average loss: 58.4544
# Epoch: 315
# Average loss: 62.3958
# Epoch: 316
# Average loss: 64.0047
# Epoch: 317
# Average loss: 61.6068
# Epoch: 318
# Average loss: 60.5028
# Epoch: 319
# Average loss: 61.8357
# Epoch: 320
# Average loss: 59.4753
# Epoch: 321
# Average loss: 58.0677
# Epoch: 322
# Average loss: 57.7531
# Epoch: 323
# Average loss: 58.2662
# Epoch: 324
# Average loss: 61.1380
# Epoch: 325
# Average loss: 59.1621
# Epoch: 326
# Average loss: 62.5970
# Epoch: 327
# Average loss: 62.3803
# Epoch: 328
# Average loss: 57.8060
# Epoch: 329
# Average loss: 56.8104
# Epoch: 330
# Average loss: 57.4093
# Epoch: 331
# Average loss: 68.2373
# Epoch: 332
# Average loss: 61.9878
# Epoch: 333
# Average loss: 61.4071
# Epoch: 334
# Average loss: 61.7158
# Epoch: 335
# Average loss: 68.6860
# Epoch: 336
# Average loss: 60.8658
# Epoch: 337
# Average loss: 58.6356
# Epoch: 338
# Average loss: 59.9380
# Epoch: 339
# Average loss: 59.8517
# Epoch: 340
# Average loss: 62.4127
# Epoch: 341
# Average loss: 58.7102
# Epoch: 342
# Average loss: 60.8604
# Epoch: 343
# Average loss: 58.5981
# Epoch: 344
# Average loss: 58.4330
# Epoch: 345
# Average loss: 58.4669
# Epoch: 346
# Average loss: 61.0350
# Epoch: 347
# Average loss: 63.4305
# Epoch: 348
# Average loss: 59.6167
# Epoch: 349
# Average loss: 61.5604
# Epoch: 350
# Average loss: 56.7129
# Epoch: 351
# Average loss: 66.7854
# Epoch: 352
# Average loss: 70.4298
# Epoch: 353
# Average loss: 62.3224
# Epoch: 354
# Average loss: 61.1984
# Epoch: 355
# Average loss: 63.7164
# Epoch: 356
# Average loss: 80.5162
# Epoch: 357
# Average loss: 65.5531
# Epoch: 358
# Average loss: 69.6693
# Epoch: 359
# Average loss: 67.5631
# Epoch: 360
# Average loss: 66.1444
# Epoch: 361
# Average loss: 70.6802
# Epoch: 362
# Average loss: 58.7893
# Epoch: 363
# Average loss: 62.0833
# Epoch: 364
# Average loss: 61.4198
# Epoch: 365
# Average loss: 60.0543
# Epoch: 366
# Average loss: 65.6401
# Epoch: 367
# Average loss: 67.8223
# Epoch: 368
# Average loss: 64.2344
# Epoch: 369
# Average loss: 66.1115
# Epoch: 370
# Average loss: 62.2132
# Epoch: 371
# Average loss: 67.9517
# Epoch: 372
# Average loss: 59.5936
# Epoch: 373
# Average loss: 55.8836
# Epoch: 374
# Average loss: 56.1291
# Epoch: 375
# Average loss: 60.4033
# Epoch: 376
# Average loss: 58.6436
# Epoch: 377
# Average loss: 57.1739
# Epoch: 378
# Average loss: 57.2573
# Epoch: 379
# Average loss: 58.6108
# Epoch: 380
# Average loss: 60.0029
# Epoch: 381
# Average loss: 56.4633
# Epoch: 382
# Average loss: 57.5336
# Epoch: 383
# Average loss: 57.0913
# Epoch: 384
# Average loss: 60.4457
# Epoch: 385
# Average loss: 56.2399
# Epoch: 386
# Average loss: 59.6784
# Epoch: 387
# Average loss: 61.3210
# Epoch: 388
# Average loss: 66.2567
# Epoch: 389
# Average loss: 62.5165
# Epoch: 390
# Average loss: 60.9138
# Epoch: 391
# Average loss: 61.2157
# Epoch: 392
# Average loss: 67.0619
# Epoch: 393
# Average loss: 69.0260
# Epoch: 394
# Average loss: 55.6177
# Epoch: 395
# Average loss: 56.4380
# Epoch: 396
# Average loss: 58.5272
# Epoch: 397
# Average loss: 56.0708
# Epoch: 398
# Average loss: 58.8952
# Epoch: 399
# Average loss: 59.0576

# %% [markdown]
# ## Section 3: Perform unsupervised K-means clustering on latent space

# %%
# %matplotlib inline
z_run = rvagene.transform(train_dataset)  ## latent embeddings of training genes

############### plot 3 dimensional z plot ##################
fig = plt.figure()
ax1 = fig.add_subplot(111, projection='3d')

ax1.scatter(z_run[:,0],z_run[:,1],z_run[:,2])
plt.title("Latent space (Z)")
plt.savefig("figs/z_run_"+dataset+".png", dpi=500)
plt.show()
plt.close()

################## k means clustering on z ################
from sklearn.cluster import MiniBatchKMeans
kmeans = MiniBatchKMeans(n_clusters=4,
                         random_state=0,
                         batch_size=6,
                         max_iter=10).fit(z_run)

centers = kmeans.cluster_centers_

c_zs = kmeans.predict(z_run)
legend = dict()
hex_colors = []
counts = dict()

################## plot 3 D z with kmeans clustering ##############
for i in np.unique(c_zs):
    hex_colors.append('#%06X' % np.random.randint(0, 0xFFFFFF))
    legend[i]=hex_colors[-1]
colors = [hex_colors[int(i)] for i in c_zs]
fig = plt.figure()
ax1 = fig.add_subplot(111, projection='3d')

ax1.scatter(z_run[:,0],z_run[:,1],z_run[:,2],c=colors)

legend_elements = [Patch(facecolor=legend[i],
                         label="cluster "+str(i) ) for i in legend.keys() ]
ax1.legend(handles=legend_elements)
plt.title("Kmeans on Z")
plt.savefig("figs/clusters_"+dataset+".png", dpi=500)
plt.show()
plt.close()

# %% [markdown]
# ## Section 4:  New cluster specific gene expression time-series data generation

# %%
#################### sample points from Z around each cluster mean detected by K-means, decode and plot those points #################
samples_per_cluster = 20


length = sequence_length
x= np.linspace(0,length/1000,length)

for i in range(centers.shape[0]): ## for each cluster center
    mean = centers[i]
    cov = np.identity(centers[i].shape[0]).astype(np.double)*0.3 ## define gaussian around it to sample from

    samples = []
    for gene in range(samples_per_cluster): ## sample points from Z  
        sample = np.random.multivariate_normal(mean,cov).astype(np.double)
        samples.append(sample)
        #print("sample ",gene,"for cluster ", i,": ",sample)
    torch_samples = torch.from_numpy(np.array(samples)).float()

    mean_to_torch = torch.from_numpy(np.array([mean]*samples_per_cluster)).float()
    if torch.cuda.is_available():
        dev = "cuda:0"
    else:
        dev = "cpu"
    device = torch.device(dev)
    torch_samples = torch_samples.to(device)
    mean_to_torch = mean_to_torch.to(device)
    device = torch.device("cpu")
    ### decode sampled point from  Z to get new generated data
    regen = np.squeeze((rvagene.decoder.forward(torch_samples)).to(device).data.numpy())
    mean_regen = np.squeeze((rvagene.decoder.forward(mean_to_torch)).to(device).data.numpy())

    ############### plot decoded cluster means ##############
    for gene in range(samples_per_cluster):
        plt.plot(x,regen[:,gene],alpha=0.6,linewidth=0.9)
    plt.plot(x,mean_regen[:,0],color="#000000")
    plt.legend(handles=[legend_elements[i]])
    plt.savefig("figs/generated_cluster_" + dataset + str(i) + ".png", dpi=500)
    plt.show()
    plt.close()
